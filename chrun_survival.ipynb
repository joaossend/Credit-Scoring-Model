# %%
import pandas as pd
import seaborn as sns
import numpy as np
import warnings
warnings.filterwarnings("ignore")
from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split
from numpy import random
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix
from sklearn.feature_selection import RFECV
from sklearn.linear_model import LogisticRegression, RidgeClassifier
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix,mean_squared_error
from sklearn.neural_network import MLPClassifier
from imblearn.under_sampling import RandomUnderSampler
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import NearMiss
from sklearn.neighbors import KNeighborsClassifier

import xgboost as xgb
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, roc_auc_score, roc_curve
from scipy.ndimage.filters import gaussian_filter1d

# %%
import numpy as np
import pandas as pd

# Libraries for graphs
import matplotlib.pyplot as plt
import seaborn as sns

# Sklearn cross validation and split the dataset
from sklearn.model_selection import train_test_split, cross_validate

# Sklearn utils and pipelines
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.compose import make_column_selector as selector
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import make_pipeline
from sklearn.metrics import confusion_matrix, mutual_info_score, recall_score, accuracy_score, precision_score, f1_score
from sklearn_pandas import DataFrameMapper 
from sksurv.util import Surv

# Sklearn models
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, VotingClassifier
from sksurv.ensemble import ExtraSurvivalTrees, RandomSurvivalForest, GradientBoostingSurvivalAnalysis

# Statsmodels for VIF
from statsmodels.stats.outliers_influence import variance_inflation_factor

# Implementation of the XGBoost
import xgboost as xgb

# Lifelines for survival analysis
from lifelines.plotting import qq_plot
from lifelines import KaplanMeierFitter, WeibullFitter, WeibullAFTFitter, CoxPHFitter
from lifelines.utils import concordance_index

# For building the networks and some useful functions
import torch  
import torchtuples as tt 
from summarytools import dfSummary

# Deep learning for survival analysis
# from pycox.models import DeepHitSingle
# from pycox.evaluation import EvalSurv

# %%
df = pd.read_csv('churn_survival.csv')

# %%
# https://www.kaggle.com/code/caralosal/survival-models-vs-ml-models-benchmark-churn-tel/notebook

# %%
pd.set_option('display.max_columns', None)

# %%
dfSummary(df)
# Out:
# <style type="text/css">
# #T_23c9d thead>tr>th {
#   text-align: left;
# }
# #T_23c9d_row0_col0, #T_23c9d_row1_col0, #T_23c9d_row2_col0, #T_23c9d_row3_col0, #T_23c9d_row4_col0, #T_23c9d_row5_col0, #T_23c9d_row6_col0, #T_23c9d_row7_col0, #T_23c9d_row8_col0, #T_23c9d_row9_col0, #T_23c9d_row10_col0, #T_23c9d_row11_col0, #T_23c9d_row12_col0, #T_23c9d_row13_col0, #T_23c9d_row14_col0, #T_23c9d_row15_col0, #T_23c9d_row16_col0, #T_23c9d_row17_col0, #T_23c9d_row18_col0, #T_23c9d_row19_col0, #T_23c9d_row20_col0 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 5%;
#   max-width: 50px;
#   min-width: 20px;
# }
# #T_23c9d_row0_col1, #T_23c9d_row1_col1, #T_23c9d_row2_col1, #T_23c9d_row3_col1, #T_23c9d_row4_col1, #T_23c9d_row5_col1, #T_23c9d_row6_col1, #T_23c9d_row7_col1, #T_23c9d_row8_col1, #T_23c9d_row9_col1, #T_23c9d_row10_col1, #T_23c9d_row11_col1, #T_23c9d_row12_col1, #T_23c9d_row13_col1, #T_23c9d_row14_col1, #T_23c9d_row15_col1, #T_23c9d_row16_col1, #T_23c9d_row17_col1, #T_23c9d_row18_col1, #T_23c9d_row19_col1, #T_23c9d_row20_col1 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 15%;
#   max-width: 200px;
#   min-width: 100px;
#   word-break: break-word;
# }
# #T_23c9d_row0_col2, #T_23c9d_row1_col2, #T_23c9d_row2_col2, #T_23c9d_row3_col2, #T_23c9d_row4_col2, #T_23c9d_row5_col2, #T_23c9d_row6_col2, #T_23c9d_row7_col2, #T_23c9d_row8_col2, #T_23c9d_row9_col2, #T_23c9d_row10_col2, #T_23c9d_row11_col2, #T_23c9d_row12_col2, #T_23c9d_row13_col2, #T_23c9d_row14_col2, #T_23c9d_row15_col2, #T_23c9d_row16_col2, #T_23c9d_row17_col2, #T_23c9d_row18_col2, #T_23c9d_row19_col2, #T_23c9d_row20_col2 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 30%;
#   min-width: 100px;
# }
# #T_23c9d_row0_col3, #T_23c9d_row1_col3, #T_23c9d_row2_col3, #T_23c9d_row3_col3, #T_23c9d_row4_col3, #T_23c9d_row5_col3, #T_23c9d_row6_col3, #T_23c9d_row7_col3, #T_23c9d_row8_col3, #T_23c9d_row9_col3, #T_23c9d_row10_col3, #T_23c9d_row11_col3, #T_23c9d_row12_col3, #T_23c9d_row13_col3, #T_23c9d_row14_col3, #T_23c9d_row15_col3, #T_23c9d_row16_col3, #T_23c9d_row17_col3, #T_23c9d_row18_col3, #T_23c9d_row19_col3, #T_23c9d_row20_col3 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 25%;
#   min-width: 100px;
# }
# #T_23c9d_row0_col4, #T_23c9d_row1_col4, #T_23c9d_row2_col4, #T_23c9d_row3_col4, #T_23c9d_row4_col4, #T_23c9d_row5_col4, #T_23c9d_row6_col4, #T_23c9d_row7_col4, #T_23c9d_row8_col4, #T_23c9d_row9_col4, #T_23c9d_row10_col4, #T_23c9d_row11_col4, #T_23c9d_row12_col4, #T_23c9d_row13_col4, #T_23c9d_row14_col4, #T_23c9d_row15_col4, #T_23c9d_row16_col4, #T_23c9d_row17_col4, #T_23c9d_row18_col4, #T_23c9d_row19_col4, #T_23c9d_row20_col4 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 20%;
#   min-width: 150px;
# }
# #T_23c9d_row0_col5, #T_23c9d_row1_col5, #T_23c9d_row2_col5, #T_23c9d_row3_col5, #T_23c9d_row4_col5, #T_23c9d_row5_col5, #T_23c9d_row6_col5, #T_23c9d_row7_col5, #T_23c9d_row8_col5, #T_23c9d_row9_col5, #T_23c9d_row10_col5, #T_23c9d_row11_col5, #T_23c9d_row12_col5, #T_23c9d_row13_col5, #T_23c9d_row14_col5, #T_23c9d_row15_col5, #T_23c9d_row16_col5, #T_23c9d_row17_col5, #T_23c9d_row18_col5, #T_23c9d_row19_col5, #T_23c9d_row20_col5 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 10%;
# }
# </style>
# <table id="T_23c9d">
#   <caption><strong>Data Frame Summary</strong><br>df<br>Dimensions: 7,043 x 21<br>Duplicates: 0</caption>
#   <thead>
#     <tr>
#       <th id="T_23c9d_level0_col0" class="col_heading level0 col0" >No</th>
#       <th id="T_23c9d_level0_col1" class="col_heading level0 col1" >Variable</th>
#       <th id="T_23c9d_level0_col2" class="col_heading level0 col2" >Stats / Values</th>
#       <th id="T_23c9d_level0_col3" class="col_heading level0 col3" >Freqs / (% of Valid)</th>
#       <th id="T_23c9d_level0_col4" class="col_heading level0 col4" >Graph</th>
#       <th id="T_23c9d_level0_col5" class="col_heading level0 col5" >Missing</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_23c9d_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_23c9d_row0_col1" class="data row0 col1" ><strong>customerID</strong><br>[object]</td>
#       <td id="T_23c9d_row0_col2" class="data row0 col2" >1. 7590-VHVEG<br>2. 3791-LGQCY<br>3. 6008-NAIXK<br>4. 5956-YHHRX<br>5. 5365-LLFYV<br>6. 5855-EIBDE<br>7. 8166-ZZTFS<br>8. 0129-KPTWJ<br>9. 9128-CPXKI<br>10. 9509-MPYOD<br>11. other</td>
#       <td id="T_23c9d_row0_col3" class="data row0 col3" >1 (0.0%)<br>1 (0.0%)<br>1 (0.0%)<br>1 (0.0%)<br>1 (0.0%)<br>1 (0.0%)<br>1 (0.0%)<br>1 (0.0%)<br>1 (0.0%)<br>1 (0.0%)<br>7,033 (99.9%)</td>
#       <td id="T_23c9d_row0_col4" class="data row0 col4" ><img src = "......"></img></td>
#       <td id="T_23c9d_row0_col5" class="data row0 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_23c9d_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_23c9d_row1_col1" class="data row1 col1" ><strong>gender</strong><br>[object]</td>
#       <td id="T_23c9d_row1_col2" class="data row1 col2" >1. Male<br>2. Female</td>
#       <td id="T_23c9d_row1_col3" class="data row1 col3" >3,555 (50.5%)<br>3,488 (49.5%)</td>
#       <td id="T_23c9d_row1_col4" class="data row1 col4" ><img src = "......"></img></td>
#       <td id="T_23c9d_row1_col5" class="data row1 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_23c9d_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_23c9d_row2_col1" class="data row2 col1" ><strong>SeniorCitizen</strong><br>[int64]</td>
#       <td id="T_23c9d_row2_col2" class="data row2 col2" >Mean (sd) : 0.2 (0.4)<br>min < med < max:<br>0.0 < 0.0 < 1.0<br>IQR (CV) : 0.0 (0.4)</td>
#       <td id="T_23c9d_row2_col3" class="data row2 col3" >2 distinct values</td>
#       <td id="T_23c9d_row2_col4" class="data row2 col4" ><img src = "......"></img></td>
#       <td id="T_23c9d_row2_col5" class="data row2 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_23c9d_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_23c9d_row3_col1" class="data row3 col1" ><strong>Partner</strong><br>[object]</td>
#       <td id="T_23c9d_row3_col2" class="data row3 col2" >1. No<br>2. Yes</td>
#       <td id="T_23c9d_row3_col3" class="data row3 col3" >3,641 (51.7%)<br>3,402 (48.3%)</td>
#       <td id="T_23c9d_row3_col4" class="data row3 col4" ><img src = "......"></img></td>
#       <td id="T_23c9d_row3_col5" class="data row3 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_23c9d_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_23c9d_row4_col1" class="data row4 col1" ><strong>Dependents</strong><br>[object]</td>
#       <td id="T_23c9d_row4_col2" class="data row4 col2" >1. No<br>2. Yes</td>
#       <td id="T_23c9d_row4_col3" class="data row4 col3" >4,933 (70.0%)<br>2,110 (30.0%)</td>
#       <td id="T_23c9d_row4_col4" class="data row4 col4" ><img src = "......"></img></td>
#       <td id="T_23c9d_row4_col5" class="data row4 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_23c9d_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_23c9d_row5_col1" class="data row5 col1" ><strong>tenure</strong><br>[int64]</td>
#       <td id="T_23c9d_row5_col2" class="data row5 col2" >Mean (sd) : 32.4 (24.6)<br>min < med < max:<br>0.0 < 29.0 < 72.0<br>IQR (CV) : 46.0 (1.3)</td>
#       <td id="T_23c9d_row5_col3" class="data row5 col3" >73 distinct values</td>
#       <td id="T_23c9d_row5_col4" class="data row5 col4" ><img src = "......"></img></td>
#       <td id="T_23c9d_row5_col5" class="data row5 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_23c9d_row6_col0" class="data row6 col0" >7</td>
#       <td id="T_23c9d_row6_col1" class="data row6 col1" ><strong>PhoneService</strong><br>[object]</td>
#       <td id="T_23c9d_row6_col2" class="data row6 col2" >1. Yes<br>2. No</td>
#       <td id="T_23c9d_row6_col3" class="data row6 col3" >6,361 (90.3%)<br>682 (9.7%)</td>
#       <td id="T_23c9d_row6_col4" class="data row6 col4" ><img src = "......"></img></td>
#       <td id="T_23c9d_row6_col5" class="data row6 col5" >0<br>(0.0%)</td>

# %%
df[df['customerID']=='7590-VHVEG']
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No          No          No              No  Month-to-month
#
#   PaperlessBilling     PaymentMethod  MonthlyCharges TotalCharges Churn
# 0              Yes  Electronic check           29.85        29.85    No

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No          No          No              No  Month-to-month
# 1              Yes          No          No              No        One year
# 2               No          No          No              No  Month-to-month
# 3              Yes         Yes          No              No        One year
# 4               No          No          No              No  Month-to-month
#
#   PaperlessBilling              PaymentMethod  MonthlyCharges TotalCharges  \
# 0              Yes           Electronic check           29.85        29.85
# 1               No               Mailed check           56.95       1889.5
# 2              Yes               Mailed check           53.85       108.15
# 3               No  Bank transfer (automatic)           42.30      1840.75
# 4              Yes           Electronic check           70.70       151.65
#
#   Churn
# 0    No
# 1    No
# 2   Yes
# 3    No
# 4   Yes

# %%
# tenure = numero de meses que o clietnes sobreviveu
# churn, seria prepay

# %%
df = df.drop(index = df[df.loc[:, "TotalCharges"] == ' '].index)
